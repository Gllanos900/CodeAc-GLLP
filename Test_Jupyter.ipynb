# %%
def count_function (x,y):
  A = x + 10+1 
  B = y + 10+2
  C = (A+B)/2 
  print ("The solve eq of this numbers is plus", C)

count_function (100,3.2)
# Out:
# The solve eq of this numbers is plus 63.1
